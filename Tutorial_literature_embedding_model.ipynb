# %%
import pathlib
import sys
sys.path.append('lib')  
import Building_Literature_Embedding_Model as edg

# %%
# Define hyper-parameters
context_size = 4
min_count = 3
min_size = 2
dimension = 128
num_sampled = 64
batch_size = 256 
epoch = 30

# %%
root_path = '../data/preprocessed_data'
output='../data/tutorial_literature_embedding_model'  
  
vocab_dir = output + '/vocab/'
preprocessed_path = root_path + '/preprocessed/data.doc.txt'
model_path = output 
logs_dir = vocab_dir+'/logs'
gene2doc_dir = logs_dir+'/gene2doc' 

pathlib.Path(logs_dir).mkdir(parents=True, exist_ok=True)
pathlib.Path(gene2doc_dir).mkdir(parents=True, exist_ok=True) 
pathlib.Path(model_path).mkdir(parents=True, exist_ok=True)

# %%
print("==== Generating Training Data for Literature Embedding Model")
eg=edg.building_embedding_model()
eg.setting(preprocessed_path, vocab_dir, logs_dir, gene2doc_dir)

print("==== Creating Vocabulary ===")
eg.creating_vocab(min_count = min_count, min_size = min_size)
# Out:
# ==== Generating Training Data for Literature Embedding Model
# ==== Creating Vocabulary ===
# 241315

# %%
print("=== Checking If Data Generation Is Correct ===")
eg.checking_gene2doc_generation(context_size)
# Out:
# === Checking If Data Generation Is Correct ===
# == Examples:  #LINC01128
# integrated -> #LINC01128
# analysis -> #LINC01128
# risk -> #LINC01128
# score -> #LINC01128
# analysis -> #LINC01128
# risk -> #LINC01128
# score -> #LINC01128
# predicting -> #LINC01128
# risk -> #LINC01128
# score -> #LINC01128
# predicting -> #LINC01128
# prognosis -> #LINC01128
# score -> #LINC01128
# predicting -> #LINC01128
# prognosis -> #LINC01128
# cerna -> #LINC01128
# predicting -> #LINC01128
# prognosis -> #LINC01128
# cerna -> #LINC01128
# network -> #LINC01128
# prognosis -> #LINC01128
# cerna -> #LINC01128
# network -> #LINC01128
# differentially -> #LINC01128
# cerna -> #LINC01128
# network -> #LINC01128
# differentially -> #LINC01128
# expressed -> #LINC01128
# network -> #LINC01128
# differentially -> #LINC01128

# %%
#print("=== Creating Training Data For Fig. 3(a) and (b) in our paper ===")
eg.creating_training_data_for_gene2doc(context_size)
 
#print("=== Starting Model Training For Figs.2-3 ===")
eg.model_setting(dimension=dimension, num_sampled=num_sampled)
eg.starting_sorting(model_path)
eg.model_training(epoch=epoch, batch_size=batch_size, window_size = context_size)
# Out:
# cbow  19526
# starting making data
# 0 gene2doc
# WARNING:tensorflow:From lib\Building_Literature_Embedding_Model.py:184: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From lib\Building_Literature_Embedding_Model.py:189: The name tf.truncated_normal is deprecated. Please use tf.random.truncated_normal instead.
#
# WARNING:tensorflow:From lib\Building_Literature_Embedding_Model.py:192: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From C:\Users\jim19007\Anaconda3\envs\visualization\lib\site-packages\tensorflow_core\python\ops\nn_impl.py:183: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From lib\Building_Literature_Embedding_Model.py:206: The name tf.summary.scalar is deprecated. Please use tf.compat.v1.summary.scalar instead.
#
# WARNING:tensorflow:From lib\Building_Literature_Embedding_Model.py:208: The name tf.train.GradientDescentOptimizer is deprecated. Please use tf.compat.v1.train.GradientDescentOptimizer instead.
#
# WARNING:tensorflow:From lib\Building_Literature_Embedding_Model.py:210: calling reduce_sum_v1 (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead
# WARNING:tensorflow:From lib\Building_Literature_Embedding_Model.py:216: The name tf.summary.merge_all is deprecated. Please use tf.compat.v1.summary.merge_all instead.
#
# WARNING:tensorflow:From lib\Building_Literature_Embedding_Model.py:217: The name tf.global_variables_initializer is deprecated. Please use tf.compat.v1.global_variables_initializer instead.
#
# WARNING:tensorflow:From lib\Building_Literature_Embedding_Model.py:218: The name tf.train.Saver is deprecated. Please use tf.compat.v1.train.Saver instead.
#
# WARNING:tensorflow:From lib\Building_Literature_Embedding_Model.py:221: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# WARNING:tensorflow:From lib\Building_Literature_Embedding_Model.py:222: The name tf.summary.FileWriter is deprecated. Please use tf.compat.v1.summary.FileWriter instead.
#
# Initialized
# WARNING:tensorflow:From lib\Building_Literature_Embedding_Model.py:259: The name tf.RunMetadata is deprecated. Please use tf.compat.v1.RunMetadata instead.
#
# Average loss at step  0 / 30 :  17.32608036745837
# time:  354.0521354675293
# Nearest to 3-year: samples, problem, hand, #SAA1, kir, signaling, #FMNL2, responded,
# Nearest to analysis: control, ductal, p-value, residue, hypertrophic, agents, accuracy, 22q11,
# Nearest to verified: paralysis, vivo, statistically, accelerated, associations, controls, poi, currently,
# Nearest to prognosis: mechanical, roles, objectives, mineral, thrombin, dopamine, fork, association,
# Nearest to myeloma: epsilon4, correlated, patients, postoperative, homologues, pharmacologically, toll-like, allergic,
# Nearest to integrated: pedigrees, igg, lipolysis, vivo, urothelial, atlas, #PIK3R1, #TBK1,
# Nearest to patients: craniofacial, kir, alterations, egg, chd, levels, american, perfusion,
# Nearest to prognostic: microscopy, unclear, study, apob, treating, #72, candidates, heart,
# Nearest to multiple: kir, outcomes, mimic, expression, p65, ranges, lncrnas, diet,
# Nearest to demonstrates: maintain, cca, bronchoalveolar, cd8, recognition, cancer, domain, #62,
# Nearest to omnibus: malignancy, observed, recognizes, ways, #D1, reconstituted, assembled, apoptotic,
# Nearest to raw: #DNMT3A, cells, cytidine, participates, ap-1, terminus, post-translational, recycling,
# Nearest to univariate: retrieved, challenge, evidence, created, network, #H3, human, protease,
# Nearest to tested: beta-catenin, organs, pda, ifn, corresponding, stromal, #34, levels,
# Nearest to expressed: #21, hub, deletion, glioblastoma, metastasis, decision, cross-sectional, nephropathy,
# Nearest to potential: #95, #CD8, chi, combinatorial, circular, substitutions, end, mutations,
# Average loss at step  1 / 30 :  0.9283244017092595
# time:  334.66528248786926
# Nearest to 3-year: hand, isoforms, responded, samples, #SAA1, #FMNL2, infected, problem,
# Nearest to analysis: p-value, residue, 22q11, strains, agents, copa, accuracy, eomes,
# Nearest to verified: paralysis, delta, statistically, accelerated, exerted, vivo, exerts, controls,
# Nearest to prognosis: thrombin, mechanical, segregated, termed, dopamine, fork, mineral, objectives,
# Nearest to myeloma: epsilon4, homologues, decoction, versus, pharmacologically, fractures, enhances, correlated,
# Nearest to integrated: pedigrees, igg, dehp, #PIK3R1, extract, nuclease, lipolysis, #TBK1,
# Nearest to patients: fructus, american, comprised, undergoes, src, egg, labeled, mutation,
# Nearest to prognostic: apob, moieties, feedback, microscopy, treating, protocols, candidates, units,
# Nearest to multiple: mimic, outcomes, ranges, faster, kir, #ITGB8, p65, lncrnas,
# Nearest to demonstrates: axis, domain, binds, cca, bronchoalveolar, urea, maintain, cd8,
# Nearest to omnibus: fructus, recognizes, drainage, malignancy, observed, pumps, cleaves, reconstituted,
# Nearest to raw: cytidine, terminus, participates, #DNMT3A, cells, #-#, degraded, ap-1,
# Nearest to univariate: retrieved, challenge, created, #SLC44A1, protease, #H3, evidence, aurka,
# Nearest to tested: pda, organs, beta-catenin, corresponding, homolog, ifn, #34, assemblies,
# Nearest to expressed: mtrr, deletion, represses, subfamilies, #TLR4, fructus, formed, reversible,
# Nearest to potential: #95, extract, substitutions, produced, applying, pomc, circular, acc,
# Average loss at step  2 / 30 :  0.598487575375946
# time:  334.18419647216797
# Nearest to 3-year: responded, #FMNL2, hand, rab1a, #SAA1, thyrotrophs, samples, dehydrogenases,
# Nearest to analysis: p-value, copa, 22q11, maturing, strains, residue, nachr, eomes,
# Nearest to verified: paralysis, delta, gtl2, accelerated, exerted, vivo, statistically, spans,
# Nearest to prognosis: segregated, thrombin, mechanical, termed, fork, mineral, kim, providers,
# Nearest to myeloma: epsilon4, homologues, decoction, pharmacologically, fractures, pld1, versus, #EVI2B,
# Nearest to integrated: pedigrees, dehp, igg, #PIK3R1, nuclease, skills, let-7c, lipolysis,
# Nearest to patients: fructus, dbh, src, mutation, #95, undergoes, glycol, labeled,
# Nearest to prognostic: apob, moieties, #LRRTM3, feedback, ito, microscopy, mimicry, units,
# Nearest to multiple: faster, ranges, outcomes, mimic, #ITGB8, #RPS6KA2, kir, mir-802,
# Nearest to demonstrates: bronchoalveolar, urea, cca, wildtype, cd8, domain, axis, mstn,
# Nearest to omnibus: fructus, recognizes, drainage, pumps, malignancy, dim, reconstituted, cleaves,
# Nearest to raw: cytidine, participates, #DNMT3A, terminus, #NRIP1, finely, degraded, apob,
# Nearest to univariate: retrieved, #SLC44A1, challenge, evidence, created, #ATXN1L, aurka, #H3,
# Nearest to tested: pda, organs, beta-catenin, corresponding, assemblies, #ERBB4, ifn, homolog,
# Nearest to expressed: mtrr, fructus, subfamilies, represses, deletion, tal, reversible, university,
# Nearest to potential: substitutions, #95, extract, pomc, #BACE2, bcl2, dyes, applying,
# Average loss at step  3 / 30 :  0.5249622786246381
# time:  334.152462720871
# Nearest to 3-year: #FMNL2, responded, rab1a, thyrotrophs, dehydrogenases, #SAA1, epor, hand,
# Nearest to analysis: copa, maturing, 22q11, p-value, sox2-c, #B2M, fam134b, humanized,
# Nearest to verified: paralysis, gtl2, delta, exerted, #AGTR1, accelerated, vivo, spans,
# Nearest to prognosis: segregated, thrombin, providers, laparotomy, jian, mechanical, esr, kim,
# Nearest to myeloma: epsilon4, homologues, decoction, pharmacologically, pld1, fractures, #RNF141, #EVI2B,
# Nearest to integrated: pedigrees, dehp, nuclease, #PIK3R1, igg, let-7c, skills, lipolysis,
# Nearest to patients: dbh, #95, fructus, mutation, src, nonsense, congenic, clinical,
# Nearest to prognostic: apob, moieties, #LRRTM3, ito, mimicry, feedback, #GSE20685, units,
# Nearest to multiple: faster, ranges, mimic, #ITGB8, outcomes, #RPS6KA2, ether, mir-802,
# Nearest to demonstrates: bronchoalveolar, wildtype, cca, urea, cd8, district, maintain, mstn,
# Nearest to omnibus: fructus, recognizes, drainage, pumps, malignancy, dim, reconstituted, cleaves,
# Nearest to raw: cytidine, #DNMT3A, participates, terminus, #NRIP1, finely, #-resistant, degraded,
# Nearest to univariate: #SLC44A1, retrieved, challenge, #ATXN1L, evidence, created, crtc2, structure-based,
# Nearest to tested: pda, organs, beta-catenin, #ERBB4, assemblies, exported, #ETV1, oxygen-glucose,
# Nearest to expressed: mtrr, fructus, tal, subfamilies, represses, isogenic, puncta, totally,
# Nearest to potential: substitutions, #BACE2, pomc, bcl2, dyes, #KCNE1, manual, acr,
# Average loss at step  4 / 30 :  0.49412913959476384
# time:  334.4447491168976
# Nearest to 3-year: #FMNL2, rab1a, thyrotrophs, dehydrogenases, responded, #SAA1, epor, lec,
# Nearest to analysis: copa, maturing, genes, fam134b, #B2M, sox2-c, gene, bay,
# Nearest to verified: paralysis, gtl2, #AGTR1, delta, spans, accelerated, exerted, vivo,
# Nearest to prognosis: cancer, segregated, esr, 18q12, jian, #ZNF208, acanthopagrus, providers,
# Nearest to myeloma: epsilon4, homologues, decoction, pharmacologically, pld1, #RNF141, #EVI2B, fractures,
# Nearest to integrated: pedigrees, let-7c, dehp, nuclease, #PIK3R1, skills, igg, tmie,
# Nearest to patients: clinical, #95, dbh, fructus, nonsense, src, congenic, mutation,
# Nearest to prognostic: moieties, #LRRTM3, apob, #GSE20685, mimicry, feedback, xbp1, yfcs,
# Nearest to multiple: faster, ranges, #ITGB8, #RPS6KA2, mir-802, mimic, ether, outcomes,
# Nearest to demonstrates: bronchoalveolar, wildtype, district, urea, cca, fbxo32, cd8, mstn,
# Nearest to omnibus: fructus, pumps, recognizes, drainage, malignancy, dim, reconstituted, cleaves,
# Nearest to raw: cytidine, #DNMT3A, finely, #NRIP1, terminus, participates, #-resistant, rotation,
# Nearest to univariate: #SLC44A1, retrieved, challenge, #ATXN1L, crtc2, sonneratia, invadosomes, gdr1,
# Nearest to tested: pda, organs, oxygen-glucose, #ERBB4, exported, krtap6-3, mir-184, beta-catenin,
# Nearest to expressed: mtrr, fructus, tal, isogenic, puncta, subfamilies, totally, #RUVBL2,
# Nearest to potential: #BACE2, substitutions, pomc, acr, bcl2, #KCNE1, dyes, ncapg,
# Average loss at step  5 / 30 :  0.4680368695443827
# time:  334.3633966445923
# Nearest to 3-year: #FMNL2, thyrotrophs, rab1a, dehydrogenases, responded, epor, lec, #SAA1,
# Nearest to analysis: copa, maturing, fam134b, genes, #PRPF8, accuracy, #B2M, n-glycans,
# Nearest to verified: paralysis, gtl2, #AGTR1, delta, spans, equations, bpaf, exerted,
# Nearest to prognosis: cancer, acanthopagrus, salmonids, #ZNF208, 18q12, esr, #EFNA1, survival,
# Nearest to myeloma: epsilon4, homologues, #RNF141, pld1, pharmacologically, decoction, #EVI2B, circ-itch,
# Nearest to integrated: pedigrees, let-7c, dehp, nuclease, skills, #PIK3R1, degs, igg,
# Nearest to patients: clinical, #95, dbh, fructus, nonsense, maxilla, congenic, src,
# Nearest to prognostic: #LRRTM3, moieties, apob, #GSE20685, yfcs, mimicry, xbp1, #SQSTM1,
# Nearest to multiple: ranges, faster, #ITGB8, mir-802, #RPS6KA2, ether, dan, mimic,
# Nearest to demonstrates: bronchoalveolar, district, cca, wildtype, fbxo32, #HSPA1L, #NANOS3, urea,
# Nearest to omnibus: fructus, pumps, recognizes, malignancy, drainage, mlu, dim, #CEP89,
# Nearest to raw: cytidine, finely, #DNMT3A, #NRIP1, #-resistant, terminus, participates, rotation,
# Nearest to univariate: #SLC44A1, retrieved, sonneratia, invadosomes, challenge, #ATXN1L, crtc2, gdr1,
# Nearest to tested: pda, organs, krtap6-3, oxygen-glucose, exported, mir-184, #ERBB4, #ADGRE3,
# Nearest to expressed: mtrr, fructus, tal, isogenic, puncta, calm, #RUVBL2, totally,
# Nearest to potential: #BACE2, substitutions, acr, pomc, ncapg, bcl2, #KCNE1, fractures,
# Average loss at step  6 / 30 :  0.4562230913938876
# time:  334.91637325286865
# Nearest to 3-year: #FMNL2, rab1a, thyrotrophs, dehydrogenases, epor, lec, responded, #SAA1,
# Nearest to analysis: copa, fam134b, genes, maturing, accuracy, n-glycans, sox2-c, bay,
# Nearest to verified: paralysis, gtl2, #AGTR1, bpaf, equations, spans, exerted, delta,
# Nearest to prognosis: cancer, survival, acanthopagrus, salmonids, prognostic, #EFNA1, metastasis, 18q12,
# Nearest to myeloma: epsilon4, #RNF141, pld1, homologues, circ-itch, pharmacologically, decoction, #EVI2B,
# Nearest to integrated: pedigrees, let-7c, degs, skills, dehp, nuclease, #PIK3R1, #SCGB1D2,
# Nearest to patients: clinical, dbh, #95, fructus, nonsense, maxilla, congenic, #WNT3,
# Nearest to prognostic: #LRRTM3, moieties, survival, yfcs, prognosis, #GSE20685, analysis, pancancer,
# Nearest to multiple: #ITGB8, ranges, faster, mir-802, #RPS6KA2, ether, dan, neutropenia,
# Nearest to demonstrates: bronchoalveolar, district, fbxo32, wildtype, #NANOS3, cca, #HSPA1L, attained,
# Nearest to omnibus: fructus, pumps, malignancy, recognizes, mlu, drainage, #CEP89, tailor,
# Nearest to raw: cytidine, finely, #NRIP1, #DNMT3A, #-resistant, terminus, participates, rotation,
# Nearest to univariate: #SLC44A1, retrieved, invadosomes, sonneratia, crtc2, #ATXN1L, challenge, gdr1,
# Nearest to tested: krtap6-3, organs, pda, oxygen-glucose, exported, mir-184, #ERBB4, enam,
# Nearest to expressed: mtrr, isogenic, fructus, tal, calm, puncta, #RUVBL2, totally,
# Nearest to potential: #BACE2, ncapg, dyes, pomc, acr, substitutions, bcl2, #KCNE1,
# Average loss at step  7 / 30 :  0.4395282549372594
# time:  334.3762767314911
# Nearest to 3-year: #FMNL2, thyrotrophs, rab1a, dehydrogenases, epor, lec, scadd, responded,
# Nearest to analysis: genes, copa, maturing, fam134b, accuracy, #TOMM7, vegfa-rs3025039, n-glycans,
# Nearest to verified: paralysis, gtl2, #AGTR1, bpaf, equations, spans, nup98, rpob,
# Nearest to prognosis: survival, prognostic, cancer, acanthopagrus, metastasis, salmonids, #EFNA1, #ZNF208,
# Nearest to myeloma: epsilon4, #RNF141, pld1, circ-itch, decoction, homologues, pharmacologically, #EVI2B,
# Nearest to integrated: degs, pedigrees, let-7c, skills, nuclease, #SCGB1D2, dehp, tmie,
# Nearest to patients: clinical, fructus, dbh, nonsense, #PARD3, #95, maxilla, #WNT3,
# Nearest to prognostic: survival, prognosis, #LRRTM3, moieties, yfcs, analysis, #GSE20685, pancancer,
# Nearest to multiple: #ITGB8, ranges, mir-802, faster, dan, ether, #RPS6KA2, pellets,
# Nearest to demonstrates: bronchoalveolar, district, fbxo32, #HSPA1L, #NANOS3, attained, wildtype, acsl,
# Nearest to omnibus: fructus, pumps, malignancy, mlu, recognizes, drainage, #CEP89, tailor,
# Nearest to raw: cytidine, finely, #NRIP1, #-resistant, #DNMT3A, terminus, stat5a, rotation,
# Nearest to univariate: #SLC44A1, invadosomes, retrieved, sonneratia, crtc2, #ATXN1L, gdr1, challenge,
# Nearest to tested: krtap6-3, oxygen-glucose, organs, mir-184, exported, pda, #ERBB4, refeeding,
# Nearest to expressed: mtrr, isogenic, calm, puncta, tal, fructus, #RUVBL2, totally,
# Nearest to potential: #BACE2, prp-8, mip-1alpha, #KCNE1, coxsackievirus, hardy, placodes, dyes,
# Average loss at step  8 / 30 :  0.42876235465699847
# time:  333.66432762145996
# Nearest to 3-year: thyrotrophs, #FMNL2, rab1a, dehydrogenases, epor, scadd, lec, blautia,
# Nearest to analysis: copa, genes, fam134b, accuracy, maturing, #TOMM7, terminal, sox2-c,
# Nearest to verified: paralysis, gtl2, #AGTR1, equations, bpaf, nup98, statistically, spans,
# Nearest to prognosis: survival, prognostic, metastasis, salmonids, cancer, acanthopagrus, lncrna, #EFNA1,
# Nearest to myeloma: epsilon4, #RNF141, pld1, circ-itch, decoction, #SORT1, #EVI2B, homologues,
# Nearest to integrated: degs, pedigrees, let-7c, skills, nuclease, #SCGB1D2, atlas, tmie,
# Nearest to patients: clinical, fructus, #PARD3, maxilla, dbh, sqt, #WNT3, nonsense,
# Nearest to prognostic: prognosis, survival, #LRRTM3, moieties, yfcs, analysis, signature, pancancer,
# Nearest to multiple: #ITGB8, mir-802, ranges, dan, faster, ether, pellets, #RPS6KA2,
# Nearest to demonstrates: bronchoalveolar, district, fbxo32, #HSPA1L, #NANOS3, attained, acsl, tox,
# Nearest to omnibus: fructus, pumps, mlu, malignancy, recognizes, #CEP89, tailor, drainage,
# Nearest to raw: cytidine, finely, #NRIP1, #-resistant, #DNMT3A, terminus, #rs2681492, stat5a,
# Nearest to univariate: #SLC44A1, invadosomes, sonneratia, retrieved, crtc2, #ATXN1L, gdr1, #rs10964862,
# Nearest to tested: krtap6-3, oxygen-glucose, organs, mir-184, refeeding, exported, resolvins, pda,
# Nearest to expressed: mtrr, isogenic, calm, tal, #RUVBL2, fructus, puncta, totally,
# Nearest to potential: #BACE2, prp-8, mip-1alpha, placodes, def, coxsackievirus, #KCNE1, hardy,
# Average loss at step  9 / 30 :  0.4202796170935107
# time:  338.0050582885742
# Nearest to 3-year: thyrotrophs, #FMNL2, rab1a, dehydrogenases, epor, scadd, blautia, lec,
# Nearest to analysis: copa, genes, fam134b, gene, #TOMM7, accuracy, maturing, n-glycans,
# Nearest to verified: paralysis, gtl2, #AGTR1, equations, nup98, bpaf, rpob, exerted,
# Nearest to prognosis: prognostic, survival, metastasis, salmonids, acanthopagrus, cancer, #ZNF208, lncrna,
# Nearest to myeloma: epsilon4, #RNF141, pld1, circ-itch, #SORT1, #EVI2B, decoction, homologues,
# Nearest to integrated: degs, pedigrees, let-7c, atlas, skills, #SCGB1D2, nuclease, tmie,
# Nearest to patients: clinical, fructus, #PARD3, dbh, maxilla, golgin, slc1a3, #WNT3,
# Nearest to prognostic: prognosis, survival, #LRRTM3, analysis, moieties, signature, cox, yfcs,
# Nearest to multiple: mir-802, #ITGB8, ranges, dan, ether, pellets, faster, npffr2,
# Nearest to demonstrates: bronchoalveolar, district, fbxo32, #HSPA1L, #NANOS3, attained, acsl, slc2a1,
# Nearest to omnibus: fructus, mlu, pumps, malignancy, recognizes, tailor, #CEP89, prognostic,
# Nearest to raw: cytidine, finely, #-resistant, #NRIP1, #DNMT3A, #rs2681492, terminus, #NOP4,
# Nearest to univariate: #SLC44A1, invadosomes, sonneratia, crtc2, retrieved, #ATXN1L, #rs10964862, gdr1,
# Nearest to tested: krtap6-3, oxygen-glucose, organs, mir-184, refeeding, exported, resolvins, enam,
# Nearest to expressed: mtrr, isogenic, calm, puncta, tal, fructus, #RUVBL2, totally,
# Nearest to potential: #BACE2, prp-8, mip-1alpha, def, coxsackievirus, placodes, #KCNE1, #MT1A,
# Average loss at step  10 / 30 :  0.4114893458915178
# time:  340.8742311000824
# Nearest to 3-year: thyrotrophs, #FMNL2, rab1a, dehydrogenases, blautia, scadd, epor, setd1a,
# Nearest to analysis: genes, copa, fam134b, study, hspa5, gene, #rs4895441, #DYNC1H1,
# Nearest to verified: paralysis, gtl2, #AGTR1, equations, nup98, bpaf, statistically, rpob,
# Nearest to prognosis: prognostic, survival, metastasis, salmonids, acanthopagrus, biomarker, cancer, #ZNF208,
# Nearest to myeloma: epsilon4, #RNF141, pld1, circ-itch, #SORT1, decoction, #EVI2B, #MIR150,
# Nearest to integrated: degs, pedigrees, atlas, let-7c, #SCGB1D2, skills, tmie, nuclease,
# Nearest to patients: clinical, fructus, #PARD3, maxilla, dbh, golgin, #KCNS1, tectorial,
# Nearest to prognostic: prognosis, survival, analysis, #LRRTM3, cox, signature, moieties, yfcs,
# Nearest to multiple: mir-802, ranges, #ITGB8, dan, ether, pellets, 16q12, rgo,
# Nearest to demonstrates: bronchoalveolar, district, fbxo32, #NANOS3, #HSPA1L, attained, acsl, slc2a1,
# Nearest to omnibus: fructus, mlu, malignancy, pumps, tailor, #CEP89, recognizes, prognostic,
# Nearest to raw: cytidine, finely, #-resistant, #NRIP1, #DNMT3A, #rs2681492, terminus, #NOP4,
# Nearest to univariate: #SLC44A1, invadosomes, sonneratia, crtc2, retrieved, #rs10964862, #ATXN1L, gdr1,
# Nearest to tested: krtap6-3, refeeding, oxygen-glucose, organs, mir-184, resolvins, exported, mprs,
# Nearest to expressed: mtrr, isogenic, fructus, calm, puncta, #RUVBL2, tal, mlst,
# Nearest to potential: #BACE2, prp-8, mip-1alpha, placodes, def, coxsackievirus, ophthalmopathy, hardy,
# Average loss at step  11 / 30 :  0.39983110732652594
# time:  344.81090021133423
# Nearest to 3-year: thyrotrophs, #FMNL2, rab1a, dehydrogenases, blautia, scadd, epor, setd1a,
# Nearest to analysis: genes, copa, study, gene, fam134b, #rs4895441, actin-related, identified,
# Nearest to verified: paralysis, #AGTR1, gtl2, equations, bpaf, nup98, exerted, rpob,
# Nearest to prognosis: prognostic, survival, salmonids, metastasis, acanthopagrus, tcga, biomarker, #ZNF208,
# Nearest to myeloma: epsilon4, #RNF141, pld1, circ-itch, #SORT1, #MIR150, #EVI2B, decoction,
# Nearest to integrated: degs, pedigrees, atlas, let-7c, #SCGB1D2, skills, database, tmie,
# Nearest to patients: clinical, fructus, #PARD3, maxilla, dbh, #KCNS1, #PSRC1, golgin,
# Nearest to prognostic: prognosis, survival, cox, #LRRTM3, signature, analysis, moieties, yfcs,
# Nearest to multiple: mir-802, ranges, #ITGB8, dan, pellets, ether, rgo, 16q12,
# Nearest to demonstrates: bronchoalveolar, district, fbxo32, #NANOS3, #HSPA1L, slc2a1, attained, gpibd,
# Nearest to omnibus: fructus, mlu, malignancy, pumps, tailor, #CEP89, prognostic, recognizes,
# Nearest to raw: cytidine, finely, #-resistant, #NRIP1, #DNMT3A, #rs2681492, terminus, #NOP4,
# Nearest to univariate: #SLC44A1, invadosomes, sonneratia, crtc2, retrieved, #rs10964862, gdr1, #ATXN1L,
# Nearest to tested: krtap6-3, refeeding, organs, oxygen-glucose, mir-184, resolvins, enam, mprs,
# Nearest to expressed: mtrr, isogenic, calm, fructus, puncta, tal, #RUVBL2, mlst,
# Nearest to potential: #BACE2, prp-8, ophthalmopathy, placodes, hardy, def, #KCNE1, ncapg,
# Average loss at step  12 / 30 :  0.39969770146162764
# time:  357.07429122924805
# Nearest to 3-year: thyrotrophs, #FMNL2, rab1a, blautia, dehydrogenases, scadd, epor, mesecys,
# Nearest to analysis: study, genes, identified, copa, gene, fam134b, #rs4895441, #PFK1,
# Nearest to verified: paralysis, #AGTR1, bpaf, gtl2, equations, nup98, statistically, #CSF3R,
# Nearest to prognosis: prognostic, survival, salmonids, tcga, metastasis, cox, biomarker, #ZNF208,
# Nearest to myeloma: epsilon4, #RNF141, pld1, #MIR150, circ-itch, #SORT1, distally, #EVI2B,
# Nearest to integrated: degs, atlas, pedigrees, database, let-7c, #SCGB1D2, skills, tmie,
# Nearest to patients: clinical, fructus, #PARD3, dbh, maxilla, #KCNS1, slc1a3, golgin,
# Nearest to prognostic: prognosis, survival, cox, analysis, signature, #LRRTM3, yfcs, moieties,
# Nearest to multiple: ranges, mir-802, #ITGB8, dan, pellets, rgo, ether, mir-637,
# Nearest to demonstrates: district, bronchoalveolar, fbxo32, gpibd, #HSPA1L, slc2a1, #NANOS3, opiate,
# Nearest to omnibus: fructus, mlu, malignancy, pumps, tailor, prognostic, #CEP89, fitted,
# Nearest to raw: cytidine, finely, #-resistant, #rs2681492, #NRIP1, #DNMT3A, #NOP4, terminus,
# Nearest to univariate: invadosomes, #SLC44A1, sonneratia, crtc2, retrieved, #rs10964862, gdr1, acrophase,
# Nearest to tested: refeeding, krtap6-3, organs, mir-184, oxygen-glucose, resolvins, enam, mprs,
# Nearest to expressed: mtrr, isogenic, calm, fructus, puncta, #RUVBL2, tal, mlst,
# Nearest to potential: #BACE2, prp-8, methods, ophthalmopathy, placodes, def, hardy, #KCNE1,
# Average loss at step  13 / 30 :  0.39436036675232145
# time:  337.51058650016785
# Nearest to 3-year: thyrotrophs, #FMNL2, rab1a, blautia, dehydrogenases, scadd, mesecys, mmut,
# Nearest to analysis: genes, study, copa, gene, vegfa-rs3025039, #PFK1, accuracy, identified,
# Nearest to verified: paralysis, #AGTR1, bpaf, nup98, equations, gtl2, #CSF3R, rpob,
# Nearest to prognosis: prognostic, survival, salmonids, tcga, cox, metastasis, biomarker, dige,
# Nearest to myeloma: epsilon4, #RNF141, pld1, #MIR150, #SORT1, circ-itch, distally, sympk,
# Nearest to integrated: degs, database, atlas, pedigrees, #SCGB1D2, let-7c, network, tmie,
# Nearest to patients: clinical, fructus, #PARD3, maxilla, dbh, tectorial, #KCNS1, direct-acting,
# Nearest to prognostic: prognosis, survival, cox, signature, analysis, #LRRTM3, yfcs, low-risk,
# Nearest to multiple: ranges, mir-802, dan, #ITGB8, pellets, rnd, 146a-5p, mir-637,
# Nearest to demonstrates: district, fbxo32, bronchoalveolar, opiate, gpibd, slc2a1, #HSPA1L, attained,
# Nearest to omnibus: fructus, mlu, malignancy, pumps, tailor, prognostic, #CEP89, fitted,
# Nearest to raw: cytidine, finely, #-resistant, #DNMT3A, #rs2681492, #NRIP1, #NOP4, #LINC00994,
# Nearest to univariate: invadosomes, #SLC44A1, sonneratia, crtc2, #rs10964862, retrieved, acrophase, gdr1,
# Nearest to tested: refeeding, krtap6-3, organs, mir-184, oxygen-glucose, resolvins, enam, understandings,
# Nearest to expressed: mtrr, isogenic, fructus, #RUVBL2, puncta, calm, mlst, cdna,
# Nearest to potential: #BACE2, prp-8, ophthalmopathy, hardy, def, placodes, #KCNE1, methods,
# Average loss at step  14 / 30 :  0.39528786883766787
# time:  336.7903063297272
# Nearest to 3-year: thyrotrophs, #FMNL2, rab1a, blautia, mesecys, scadd, dehydrogenases, mmut,
# Nearest to analysis: study, genes, gene, copa, identified, rifampicin, #PFK1, fam134b,
# Nearest to verified: paralysis, nup98, bpaf, #AGTR1, gtl2, equations, #CSF3R, statistically,
# Nearest to prognosis: prognostic, survival, tcga, salmonids, cox, atlas, metastasis, dige,
# Nearest to myeloma: epsilon4, #RNF141, pld1, #MIR150, #SORT1, circ-itch, distally, sympk,
# Nearest to integrated: degs, database, atlas, pedigrees, network, #SCGB1D2, let-7c, skills,
# Nearest to patients: clinical, fructus, #PARD3, maxilla, direct-acting, #KCNS1, #SLC28A2, tectorial,
# Nearest to prognostic: prognosis, survival, cox, signature, analysis, low-risk, #LRRTM3, moieties,
# Nearest to multiple: ranges, mir-802, #ITGB8, dan, rnd, 146a-5p, pellets, mir-637,
# Nearest to demonstrates: district, fbxo32, opiate, slc2a1, gpibd, bronchoalveolar, attained, #rs1134367,
# Nearest to omnibus: fructus, mlu, malignancy, pumps, tailor, prognostic, #CEP89, protein-positive,
# Nearest to raw: cytidine, finely, #-resistant, #rs2681492, #DNMT3A, #NRIP1, #NOP4, #GTPBP3,
# Nearest to univariate: invadosomes, #SLC44A1, sonneratia, crtc2, #rs10964862, retrieved, acrophase, gdr1,
# Nearest to tested: refeeding, krtap6-3, organs, mir-184, understandings, enam, oxygen-glucose, connor,
# Nearest to expressed: mtrr, isogenic, fructus, calm, cdna, puncta, myelitis, mlst,
# Nearest to potential: prp-8, #BACE2, methods, ophthalmopathy, hardy, #KCNE1, mir29c, placodes,
# Average loss at step  15 / 30 :  0.38447145946751926
# time:  334.6809461116791
# Nearest to 3-year: thyrotrophs, #FMNL2, blautia, rab1a, mesecys, scadd, mmut, dehydrogenases,
# Nearest to analysis: study, gene, copa, genes, identified, #PFK1, #DYNC1H1, related,
# Nearest to verified: paralysis, bpaf, nup98, #AGTR1, #CSF3R, statistically, equations, exerted,
# Nearest to prognosis: prognostic, survival, tcga, salmonids, cox, factor-1, atlas, dige,
# Nearest to myeloma: epsilon4, #RNF141, pld1, #MIR150, #SORT1, distally, circ-itch, sympk,
# Nearest to integrated: degs, database, atlas, network, #SCGB1D2, pedigrees, let-7c, nuclease,
# Nearest to patients: clinical, fructus, maxilla, #PARD3, tectorial, #KCNS1, #SLC28A2, slc1a3,
# Nearest to prognostic: prognosis, survival, cox, signature, low-risk, #LRRTM3, tcga, analysis,
# Nearest to multiple: ranges, rnd, mir-802, #ITGB8, dan, mir-637, 146a-5p, ether,
# Nearest to demonstrates: district, opiate, fbxo32, gpibd, slc2a1, #rs1134367, attained, bronchoalveolar,
# Nearest to omnibus: fructus, mlu, malignancy, pumps, tailor, #CEP89, prognostic, protein-positive,
# Nearest to raw: cytidine, finely, #rs2681492, #DNMT3A, #-resistant, #NRIP1, #NOP4, #GTPBP3,
# Nearest to univariate: invadosomes, #SLC44A1, sonneratia, crtc2, #rs10964862, acrophase, retrieved, #SEMA7A,
# Nearest to tested: refeeding, krtap6-3, organs, mir-184, understandings, #MS4A, enam, connor,
# Nearest to expressed: mtrr, isogenic, fructus, #RUVBL2, cdna, calm, myelitis, puncta,
# Nearest to potential: prp-8, methods, ophthalmopathy, #BACE2, #KCNE1, #ABI3, mir29c, placodes,
# Average loss at step  16 / 30 :  0.3706901223558241
# time:  337.309677362442
# Nearest to 3-year: thyrotrophs, #FMNL2, blautia, rab1a, mesecys, scadd, mmut, pop4,
# Nearest to analysis: study, genes, gene, identified, related, #PFK1, actin-related, copa,
# Nearest to verified: paralysis, bpaf, #AGTR1, nup98, #CSF3R, statistically, equations, exerted,
# Nearest to prognosis: prognostic, survival, tcga, cox, salmonids, atlas, factor-1, mervl,
# Nearest to myeloma: epsilon4, #RNF141, #MIR150, pld1, #SORT1, distally, sympk, circ-itch,
# Nearest to integrated: degs, database, network, atlas, #SCGB1D2, pedigrees, let-7c, stages,
# Nearest to patients: clinical, fructus, #PARD3, #KCNS1, #PSRC1, direct-acting, cdon, #CELSR1,
# Nearest to prognostic: prognosis, survival, cox, signature, low-risk, tcga, tubulin-folding, #LRRTM3,
# Nearest to multiple: ranges, rnd, dan, mir-802, 146a-5p, mir-637, #ITGB8, ether,
# Nearest to demonstrates: gpibd, district, opiate, slc2a1, fbxo32, #rs1134367, lectin-like, recognition,
# Nearest to omnibus: fructus, mlu, malignancy, pumps, tailor, prognostic, #CEP89, protein-positive,
# Nearest to raw: finely, cytidine, #rs2681492, #DNMT3A, #-resistant, #NRIP1, #NOP4, #GTPBP3,
# Nearest to univariate: invadosomes, sonneratia, #SLC44A1, crtc2, #rs10964862, acrophase, retrieved, #SEMA7A,
# Nearest to tested: refeeding, krtap6-3, organs, mir-184, enam, #MS4A, connor, resolvins,
# Nearest to expressed: mtrr, isogenic, fructus, expression, myelitis, mlst, cdna, calm,
# Nearest to potential: methods, prp-8, ophthalmopathy, #KCNE1, #ABI3, #BACE2, phip, mir29c,
# Average loss at step  17 / 30 :  0.38060602448146347
# time:  335.32764077186584
# Nearest to 3-year: thyrotrophs, #FMNL2, blautia, mesecys, rab1a, mmut, scadd, pop4,
# Nearest to analysis: study, identified, genes, gene, related, #PFK1, performed, copa,
# Nearest to verified: paralysis, bpaf, nup98, #AGTR1, statistically, exerted, #CSF3R, rpob,
# Nearest to prognosis: prognostic, survival, tcga, cox, salmonids, atlas, mervl, factor-1,
# Nearest to myeloma: epsilon4, #RNF141, #MIR150, pld1, #SORT1, distally, sympk, circ-itch,
# Nearest to integrated: degs, database, network, atlas, #SCGB1D2, pedigrees, stages, enrichment,
# Nearest to patients: clinical, fructus, #KCNS1, #PARD3, maxilla, direct-acting, #PSRC1, cdon,
# Nearest to prognostic: prognosis, survival, cox, signature, low-risk, tcga, analysis, tubulin-folding,
# Nearest to multiple: rnd, dan, ranges, mir-637, mir-802, 146a-5p, ether, #ADAM5,
# Nearest to demonstrates: opiate, gpibd, district, slc2a1, fbxo32, #rs1134367, lectin-like, recognition,
# Nearest to omnibus: fructus, mlu, malignancy, pumps, tailor, prognostic, protein-positive, #CEP89,
# Nearest to raw: finely, cytidine, #rs2681492, #DNMT3A, #-resistant, #GTPBP3, #NRIP1, #NOP4,
# Nearest to univariate: invadosomes, sonneratia, #SLC44A1, crtc2, #rs10964862, acrophase, retrieved, #SEMA7A,
# Nearest to tested: refeeding, krtap6-3, organs, mir-184, enam, #MS4A, understandings, resolvins,
# Nearest to expressed: mtrr, fructus, isogenic, expression, cdna, cell, myelitis, #RUVBL2,
# Nearest to potential: methods, prp-8, study, using, #ABI3, #BACE2, mir29c, #KCNE1,
# Average loss at step  18 / 30 :  0.3741261704679778
# time:  336.2166519165039
# Nearest to 3-year: thyrotrophs, #FMNL2, mesecys, blautia, rab1a, pop4, mmut, scadd,
# Nearest to analysis: study, genes, identified, gene, related, #PFK1, performed, actin-related,
# Nearest to verified: paralysis, bpaf, nup98, #AGTR1, statistically, rpob, exerted, #rs12688220,
# Nearest to prognosis: prognostic, survival, tcga, cox, salmonids, atlas, database, mervl,
# Nearest to myeloma: epsilon4, #RNF141, #MIR150, pld1, distally, #SORT1, sympk, #MALAT1,
# Nearest to integrated: degs, database, network, atlas, #SCGB1D2, enrichment, stages, hub,
# Nearest to patients: clinical, fructus, #PARD3, #PSRC1, #KCNS1, direct-acting, maxilla, #CELSR1,
# Nearest to prognostic: prognosis, survival, cox, signature, low-risk, tcga, tubulin-folding, kaplan-meier,
# Nearest to multiple: rnd, mir-637, ranges, 146a-5p, ether, dan, mir-802, #K161,
# Nearest to demonstrates: opiate, gpibd, slc2a1, district, fbxo32, recognition, #rs1134367, lectin-like,
# Nearest to omnibus: fructus, mlu, pumps, malignancy, tailor, protein-positive, prognostic, hyperpigmentation,
# Nearest to raw: finely, #rs2681492, #DNMT3A, cytidine, #-resistant, #GTPBP3, #NOP4, #NRIP1,
# Nearest to univariate: sonneratia, invadosomes, #SLC44A1, crtc2, acrophase, #rs10964862, retrieved, #SEMA7A,
# Nearest to tested: refeeding, krtap6-3, mir-184, organs, enam, understandings, #MS4A, mprs,
# Nearest to expressed: mtrr, cdna, expression, fructus, cell, isogenic, kap3, myelitis,
# Nearest to potential: prp-8, using, study, methods, analysis, #ABI3, #KCNE1, confirmed,
# Average loss at step  19 / 30 :  0.3742978942234972
# time:  337.12211632728577
# Nearest to 3-year: thyrotrophs, #FMNL2, mesecys, blautia, pop4, rab1a, mmut, #BCAR1,
# Nearest to analysis: study, identified, genes, related, gene, using, data, performed,
# Nearest to verified: paralysis, bpaf, statistically, nup98, #AGTR1, exerted, #rs12688220, #CSF3R,
# Nearest to prognosis: prognostic, survival, tcga, cox, salmonids, atlas, database, mervl,
# Nearest to myeloma: epsilon4, #RNF141, #MIR150, pld1, distally, sympk, #SORT1, #MALAT1,
# Nearest to integrated: degs, database, network, atlas, enrichment, hub, #SCGB1D2, stages,
# Nearest to patients: clinical, fructus, maxilla, direct-acting, #PARD3, #CELSR1, #KCNS1, #PSRC1,
# Nearest to prognostic: prognosis, survival, cox, signature, low-risk, tcga, atlas, tubulin-folding,
# Nearest to multiple: rnd, mir-637, ether, 146a-5p, ranges, #K161, #ADAM5, dan,
# Nearest to demonstrates: opiate, slc2a1, gpibd, district, lectin-like, #CD160, fbxo32, #rs1134367,
# Nearest to omnibus: fructus, mlu, pumps, malignancy, tailor, protein-positive, hyperpigmentation, prognostic,
# Nearest to raw: finely, #rs2681492, #DNMT3A, cytidine, #GTPBP3, #-resistant, terminus, #NOP4,
# Nearest to univariate: sonneratia, invadosomes, #SLC44A1, crtc2, acrophase, #rs10964862, retrieved, #SEMA7A,
# Nearest to tested: refeeding, krtap6-3, mir-184, organs, enam, #MS4A, mprs, understandings,
# Nearest to expressed: mtrr, cdna, expression, isogenic, cell, fructus, kap3, myelitis,
# Nearest to potential: prp-8, using, methods, study, analysis, pharmaceuticals, #KCNE1, #ABI3,
# Average loss at step  20 / 30 :  0.3610544872828953
# time:  336.4479944705963
# Nearest to 3-year: thyrotrophs, #FMNL2, mesecys, blautia, pop4, mmut, #BCAR1, rab1a,
# Nearest to analysis: study, genes, identified, gene, using, related, performed, #PFK1,
# Nearest to verified: paralysis, bpaf, statistically, #AGTR1, nup98, exerted, #rs12688220, #CSF3R,
# Nearest to prognosis: prognostic, survival, tcga, cox, salmonids, atlas, database, factor-1,
# Nearest to myeloma: epsilon4, #MIR150, #RNF141, pld1, distally, #MALAT1, sympk, #SORT1,
# Nearest to integrated: degs, database, network, atlas, hub, enrichment, #SCGB1D2, stages,
# Nearest to patients: clinical, fructus, #PARD3, direct-acting, #PSRC1, maxilla, diagnosis, slc1a3,
# Nearest to prognostic: prognosis, survival, cox, signature, low-risk, tcga, atlas, kaplan-meier,
# Nearest to multiple: rnd, mir-637, ether, ranges, #ADAM5, dan, 146a-5p, #K161,
# Nearest to demonstrates: opiate, slc2a1, gpibd, district, fbxo32, #rs1134367, recognition, lectin-like,
# Nearest to omnibus: mlu, fructus, pumps, malignancy, tailor, protein-positive, hyperpigmentation, gle1,
# Nearest to raw: finely, #DNMT3A, #rs2681492, cytidine, #GTPBP3, terminus, #NOP4, #-resistant,
# Nearest to univariate: sonneratia, invadosomes, #SLC44A1, crtc2, acrophase, #SEMA7A, retrieved, #rs10964862,
# Nearest to tested: refeeding, krtap6-3, mir-184, organs, #MS4A, enam, understandings, mprs,
# Nearest to expressed: mtrr, expression, cell, cdna, fructus, isogenic, kap3, deacetylases,
# Nearest to potential: study, using, analysis, prp-8, methods, #ABI3, confirmed, #KCNE1,
# Average loss at step  21 / 30 :  0.3667656549762408
# time:  336.3993124961853
# Nearest to 3-year: thyrotrophs, #FMNL2, mesecys, blautia, pop4, #BCAR1, mmut, scadd,
# Nearest to analysis: study, identified, gene, genes, performed, using, related, data,
# Nearest to verified: bpaf, paralysis, statistically, nup98, exerted, #rs12688220, #AGTR1, #CSF3R,
# Nearest to prognosis: prognostic, survival, tcga, cox, salmonids, atlas, database, mervl,
# Nearest to myeloma: epsilon4, #MIR150, #RNF141, pld1, distally, #MALAT1, sympk, #SORT1,
# Nearest to integrated: degs, database, network, enrichment, hub, atlas, stages, #SCGB1D2,
# Nearest to patients: clinical, fructus, #PARD3, #KCNS1, progression-free, #CELSR1, direct-acting, cdon,
# Nearest to prognostic: prognosis, survival, cox, tcga, signature, low-risk, atlas, kaplan-meier,
# Nearest to multiple: rnd, mir-637, ether, #ADAM5, 146a-5p, ranges, dan, #K161,
# Nearest to demonstrates: opiate, slc2a1, gpibd, program, district, #rs1134367, #CD160, recognition,
# Nearest to omnibus: mlu, fructus, pumps, tailor, malignancy, protein-positive, prognostic, hyperpigmentation,
# Nearest to raw: finely, #DNMT3A, #rs2681492, #GTPBP3, cytidine, #NOP4, terminus, #LINC00994,
# Nearest to univariate: sonneratia, invadosomes, #SLC44A1, crtc2, acrophase, #SEMA7A, retrieved, #rs10964862,
# Nearest to tested: refeeding, krtap6-3, mir-184, #MS4A, organs, enam, understandings, mprs,
# Nearest to expressed: mtrr, cdna, expression, cell, using, indicate, isogenic, fructus,
# Nearest to potential: using, study, analysis, methods, data, prp-8, confirmed, #ABI3,
# Average loss at step  22 / 30 :  0.36477524192797284
# time:  335.9057641029358
# Nearest to 3-year: thyrotrophs, #FMNL2, mesecys, blautia, pop4, #BCAR1, mmut, scadd,
# Nearest to analysis: study, identified, genes, gene, performed, related, using, #PFK1,
# Nearest to verified: bpaf, statistically, paralysis, nup98, #rs12688220, #AGTR1, exerted, #CSF3R,
# Nearest to prognosis: prognostic, survival, tcga, cox, salmonids, atlas, database, low-risk,
# Nearest to myeloma: epsilon4, #MIR150, #RNF141, pld1, distally, #MALAT1, sympk, #SORT1,
# Nearest to integrated: degs, database, network, enrichment, hub, atlas, stages, #SCGB1D2,
# Nearest to patients: clinical, fructus, #PARD3, direct-acting, #KCNS1, #SLC28A2, cdon, #PSRC1,
# Nearest to prognostic: prognosis, survival, cox, tcga, signature, low-risk, atlas, kaplan-meier,
# Nearest to multiple: rnd, ether, mir-637, #ADAM5, role, 146a-5p, dan, ranges,
# Nearest to demonstrates: opiate, slc2a1, gpibd, program, #rs1134367, n-myristoylated, #CD160, lectin-like,
# Nearest to omnibus: mlu, fructus, pumps, tailor, malignancy, protein-positive, prognostic, dataset,
# Nearest to raw: finely, #DNMT3A, #rs2681492, #GTPBP3, terminus, #NOP4, cytidine, #LINC00994,
# Nearest to univariate: sonneratia, invadosomes, #SLC44A1, acrophase, crtc2, #SEMA7A, retrieved, #CDHR3,
# Nearest to tested: refeeding, krtap6-3, mir-184, #MS4A, understandings, organs, enam, #HBG2,
# Nearest to expressed: mtrr, expression, cell, cdna, using, cells, indicate, myelitis,
# Nearest to potential: study, using, analysis, data, methods, confirmed, prp-8, performed,
# Average loss at step  23 / 30 :  0.36184511688691184
# time:  336.79255962371826
# Nearest to 3-year: thyrotrophs, mesecys, #FMNL2, pop4, blautia, #BCAR1, mmut, scadd,
# Nearest to analysis: study, identified, genes, gene, performed, using, related, revealed,
# Nearest to verified: bpaf, statistically, paralysis, nup98, #rs12688220, investigate, topors, bmdcs,
# Nearest to prognosis: prognostic, survival, tcga, cox, salmonids, atlas, database, low-risk,
# Nearest to myeloma: epsilon4, #MIR150, #RNF141, pld1, distally, #MALAT1, sympk, #CSMD2,
# Nearest to integrated: degs, database, network, enrichment, hub, atlas, stages, differentially,
# Nearest to patients: clinical, fructus, maxilla, #SLC28A2, direct-acting, #PARD3, mafbx, #CELSR1,
# Nearest to prognostic: prognosis, survival, cox, tcga, low-risk, signature, atlas, kaplan-meier,
# Nearest to multiple: rnd, #ADAM5, ether, mir-637, role, 146a-5p, tcrs, ranges,
# Nearest to demonstrates: opiate, slc2a1, n-myristoylated, program, lectin-like, gpibd, #rs1134367, #CD160,
# Nearest to omnibus: mlu, fructus, tailor, pumps, protein-positive, malignancy, dataset, prognostic,
# Nearest to raw: finely, #DNMT3A, #rs2681492, #GTPBP3, terminus, #NOP4, psychotropic, #LINC00994,
# Nearest to univariate: sonneratia, invadosomes, #SLC44A1, acrophase, crtc2, #SEMA7A, #CDHR3, retrieved,
# Nearest to tested: refeeding, krtap6-3, mir-184, #MS4A, organs, understandings, enam, #HBG2,
# Nearest to expressed: expression, mtrr, cdna, cell, indicate, myelitis, using, identified,
# Nearest to potential: using, study, analysis, confirmed, data, methods, formats, prp-8,
# Average loss at step  24 / 30 :  0.3562252245052412
# time:  336.409912109375
# Nearest to 3-year: thyrotrophs, mesecys, pop4, blautia, #FMNL2, #BCAR1, mmut, scadd,
# Nearest to analysis: study, identified, gene, genes, performed, using, related, revealed,
# Nearest to verified: bpaf, statistically, paralysis, #rs12688220, topors, nup98, exerted, bmdcs,
# Nearest to prognosis: prognostic, survival, tcga, cox, atlas, salmonids, low-risk, database,
# Nearest to myeloma: epsilon4, #MIR150, #RNF141, pld1, #MALAT1, distally, sympk, #CSMD2,
# Nearest to integrated: degs, database, enrichment, network, hub, atlas, stages, #SCGB1D2,
# Nearest to patients: clinical, fructus, maxilla, direct-acting, methods, #CELSR1, #PARD3, #SLC28A2,
# Nearest to prognostic: prognosis, cox, survival, tcga, low-risk, signature, atlas, kaplan-meier,
# Nearest to multiple: rnd, mir-637, ether, #ADAM5, role, 146a-5p, dan, ranges,
# Nearest to demonstrates: opiate, slc2a1, n-myristoylated, program, ebna-1, re-analyzed, #CD160, lectin-like,
# Nearest to omnibus: mlu, fructus, tailor, pumps, protein-positive, dataset, prognostic, tcga,
# Nearest to raw: finely, #DNMT3A, #rs2681492, #GTPBP3, terminus, psychotropic, #NOP4, tapbpr,
# Nearest to univariate: sonneratia, invadosomes, #SLC44A1, acrophase, crtc2, #SEMA7A, #CDHR3, #rs10964862,
# Nearest to tested: refeeding, mir-184, #MS4A, krtap6-3, understandings, pygb, mprs, ap000221,
# Nearest to expressed: expression, cell, cdna, mtrr, indicate, using, cells, myelitis,
# Nearest to potential: using, study, analysis, data, methods, confirmed, including, identified,
# Average loss at step  25 / 30 :  0.3570113241031578
# time:  337.8191523551941
# Nearest to 3-year: thyrotrophs, mesecys, pop4, blautia, #BCAR1, #FMNL2, mmut, scadd,
# Nearest to analysis: study, identified, gene, genes, performed, using, including, potential,
# Nearest to verified: bpaf, statistically, paralysis, #rs12688220, bmdcs, topors, investigate, exerted,
# Nearest to prognosis: prognostic, survival, tcga, cox, atlas, salmonids, database, low-risk,
# Nearest to myeloma: epsilon4, #MIR150, #RNF141, pld1, #MALAT1, distally, timer, #CSMD2,
# Nearest to integrated: degs, database, enrichment, network, hub, stages, atlas, modules,
# Nearest to patients: clinical, fructus, direct-acting, maxilla, #CELSR1, methods, #SLC28A2, #PARD3,
# Nearest to prognostic: prognosis, survival, cox, tcga, low-risk, signature, atlas, kaplan-meier,
# Nearest to multiple: rnd, mir-637, role, #ADAM5, ether, tcrs, miglustat, 146a-5p,
# Nearest to demonstrates: opiate, slc2a1, program, n-myristoylated, ebna-1, #CD160, re-analyzed, lectin-like,
# Nearest to omnibus: mlu, fructus, dataset, tailor, protein-positive, pumps, tcga, prognostic,
# Nearest to raw: finely, #DNMT3A, #GTPBP3, #rs2681492, terminus, psychotropic, tapbpr, #NOP4,
# Nearest to univariate: sonneratia, invadosomes, #SLC44A1, acrophase, crtc2, #SEMA7A, #CDHR3, #rs10964862,
# Nearest to tested: refeeding, pygb, understandings, #MS4A, mir-184, krtap6-3, vulnerabilities, #HBG2,
# Nearest to expressed: expression, cell, using, cdna, indicate, cells, including, revealed,
# Nearest to potential: using, study, analysis, data, identified, methods, performed, confirmed,
# Average loss at step  26 / 30 :  0.3548458740461047
# time:  334.14009380340576
# Nearest to 3-year: thyrotrophs, mesecys, pop4, #BCAR1, blautia, #FMNL2, mmut, scadd,
# Nearest to analysis: study, identified, genes, using, gene, performed, including, related,
# Nearest to verified: bpaf, statistically, topors, paralysis, #rs12688220, bmdcs, sponge, nup98,
# Nearest to prognosis: prognostic, survival, tcga, cox, atlas, salmonids, database, low-risk,
# Nearest to myeloma: epsilon4, #MIR150, #RNF141, pld1, #MALAT1, distally, timer, pms2ek,
# Nearest to integrated: degs, database, enrichment, network, hub, differentially, based, atlas,
# Nearest to patients: clinical, fructus, methods, #PARD3, #SLC28A2, #PSRC1, maxilla, hospital,
# Nearest to prognostic: prognosis, cox, survival, tcga, low-risk, signature, atlas, kaplan-meier,
# Nearest to multiple: rnd, role, mir-637, #ADAM5, including, ether, #DR1, ranges,
# Nearest to demonstrates: opiate, slc2a1, program, ebna-1, n-myristoylated, recognition, re-analyzed, #CD160,
# Nearest to omnibus: mlu, fructus, dataset, tailor, protein-positive, pumps, tcga, gle1,
# Nearest to raw: finely, #GTPBP3, #rs2681492, #DNMT3A, terminus, psychotropic, #LINC00994, tapbpr,
# Nearest to univariate: sonneratia, invadosomes, #SEMA7A, #SLC44A1, acrophase, crtc2, regression, #CDHR3,
# Nearest to tested: refeeding, pygb, understandings, #MS4A, mir-184, tact1, #HBG2, mprs,
# Nearest to expressed: expression, using, cell, indicate, cdna, revealed, cells, mtrr,
# Nearest to potential: using, study, analysis, data, performed, identified, methods, confirmed,
# Average loss at step  27 / 30 :  0.3506619016755554
# time:  334.26844549179077
# Nearest to 3-year: thyrotrophs, mesecys, pop4, blautia, #BCAR1, mmut, #FMNL2, scadd,
# Nearest to analysis: study, identified, genes, gene, using, performed, related, including,
# Nearest to verified: bpaf, statistically, topors, bmdcs, sponge, paralysis, #rs12688220, nup98,
# Nearest to prognosis: prognostic, tcga, survival, cox, atlas, salmonids, low-risk, database,
# Nearest to myeloma: epsilon4, #MIR150, #RNF141, #MALAT1, pld1, distally, timer, pms2ek,
# Nearest to integrated: degs, database, enrichment, network, hub, based, modules, software,
# Nearest to patients: clinical, fructus, methods, maxilla, #SLC28A2, hospital, direct-acting, #PARD3,
# Nearest to prognostic: prognosis, cox, survival, tcga, low-risk, signature, atlas, kaplan-meier,
# Nearest to multiple: rnd, role, #ADAM5, mir-637, including, ether, #DR1, miglustat,
# Nearest to demonstrates: opiate, ebna-1, slc2a1, n-myristoylated, program, re-analyzed, #CD160, t-replete,
# Nearest to omnibus: mlu, fructus, dataset, tailor, protein-positive, tcga, modules, pumps,
# Nearest to raw: finely, #GTPBP3, #rs2681492, #DNMT3A, terminus, psychotropic, #LINC00994, advaita,
# Nearest to univariate: sonneratia, invadosomes, #SEMA7A, regression, #SLC44A1, acrophase, crtc2, #CDHR3,
# Nearest to tested: refeeding, pygb, understandings, #HBG2, tact1, #MS4A, vulnerabilities, #3000,
# Nearest to expressed: expression, cdna, using, revealed, indicate, cell, mtrr, including,
# Nearest to potential: using, study, analysis, data, performed, confirmed, identified, including,
# Average loss at step  28 / 30 :  0.3480835573076008
# time:  333.5996799468994
# Nearest to 3-year: thyrotrophs, mesecys, pop4, #BCAR1, blautia, mmut, #FMNL2, scadd,
# Nearest to analysis: study, using, identified, performed, gene, genes, revealed, data,
# Nearest to verified: bpaf, topors, statistically, bmdcs, #rs12688220, sponge, investigate, paralysis,
# Nearest to prognosis: prognostic, tcga, survival, cox, atlas, low-risk, salmonids, database,
# Nearest to myeloma: epsilon4, #MIR150, #RNF141, #MALAT1, pld1, distally, timer, ethenes,
# Nearest to integrated: degs, database, enrichment, network, hub, based, stages, software,
# Nearest to patients: clinical, fructus, methods, #SLC28A2, maxilla, hospital, progression-free, #CELSR1,
# Nearest to prognostic: prognosis, cox, survival, tcga, low-risk, signature, atlas, kaplan-meier,
# Nearest to multiple: rnd, role, #ADAM5, mir-637, ether, including, #DR1, 16q12,
# Nearest to demonstrates: opiate, ebna-1, slc2a1, n-myristoylated, program, #CD160, suspensions, re-analyzed,
# Nearest to omnibus: mlu, fructus, dataset, modules, tailor, protein-positive, tcga, pumps,
# Nearest to raw: finely, #GTPBP3, #rs2681492, terminus, #DNMT3A, psychotropic, #LINC00994, advaita,
# Nearest to univariate: sonneratia, regression, invadosomes, #SEMA7A, acrophase, #SLC44A1, crtc2, #CDHR3,
# Nearest to tested: refeeding, pygb, understandings, #HBG2, tact1, #MS4A, vulnerabilities, #3000,
# Nearest to expressed: expression, cell, cdna, revealed, using, human, cells, indicate,
# Nearest to potential: using, study, analysis, data, performed, identified, methods, confirmed,
# Average loss at step  29 / 30 :  0.34683929749765857
# time:  333.8914177417755
# Nearest to 3-year: thyrotrophs, mesecys, pop4, #BCAR1, mmut, blautia, #FMNL2, ebl,
# Nearest to analysis: study, using, identified, gene, genes, performed, potential, including,
# Nearest to verified: bpaf, topors, statistically, bmdcs, #rs12688220, sponge, paralysis, ddm,
# Nearest to prognosis: prognostic, tcga, survival, cox, low-risk, atlas, salmonids, database,
# Nearest to myeloma: epsilon4, #MIR150, #RNF141, #MALAT1, pld1, distally, ethenes, timer,
# Nearest to integrated: degs, database, enrichment, network, hub, software, enriched, based,
# Nearest to patients: clinical, fructus, methods, hospital, maxilla, #SLC28A2, #PARD3, progression-free,
# Nearest to prognostic: prognosis, cox, survival, tcga, low-risk, signature, atlas, kaplan-meier,
# Nearest to multiple: role, rnd, #ADAM5, including, ether, mir-637, #DR1, findings,
# Nearest to demonstrates: opiate, ebna-1, slc2a1, n-myristoylated, program, suspensions, re-analyzed, #CD160,
# Nearest to omnibus: mlu, dataset, fructus, modules, tailor, protein-positive, tcga, gle1,
# Nearest to raw: finely, #GTPBP3, #rs2681492, psychotropic, terminus, #DNMT3A, using, #LINC00994,
# Nearest to univariate: sonneratia, regression, invadosomes, #SEMA7A, acrophase, crtc2, #CDHR3, #SLC44A1,
# Nearest to tested: refeeding, pygb, #HBG2, #3000, tact1, understandings, #MS4A, jeg-3,
# Nearest to expressed: cell, cdna, expression, using, revealed, human, including, indicate,
# Nearest to potential: using, analysis, study, data, identified, performed, including, identify,
